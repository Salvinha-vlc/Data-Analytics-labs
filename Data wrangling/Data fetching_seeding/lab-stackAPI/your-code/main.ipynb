# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
# your code here
import json
from stackapi import StackAPI

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
SITE = StackAPI("stackoverflow")

# %%
# your code here
question1 = SITE.fetch("questions", fromdate=1561939201,todate=1562843173)

# %%
question1
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['angular',
#     'typescript',
#     'angular7',
#     'behaviorsubject',
#     'angular-changedetection'],
#    'owner': {'reputation': 267,
#     'user_id': 4180140,
#     'user_type': 'registered',
#     'accept_rate': 49,
#     'profile_image': 'https://www.gravatar.com/avatar/027154fa032e351d1dd6d7a83ff86243?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'rji rji',
#     'link': 'https://stackoverflow.com/users/4180140/rji-rji'},
#    'is_answered': True,
#    'view_count': 259,
#    'accepted_answer_id': 56924737,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1569510683,
#    'creation_date': 1562522057,
#    'question_id': 56924703,
#    'link': 'https://stackoverflow.com/questions/56924703/enable-logout-button-only-after-login-in-angular-7',
#    'title': 'enable Logout button only after Login in Angular 7'},
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here
question2 = SITE.fetch("questions", fromdate=1563148801,todate=1563235200,
                       tagged="python", sort="votes", min=5)

# %%
question2
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['python', 'sqlite', 'flask', 'sqlalchemy', 'pymysql'],
#    'owner': {'reputation': 4259,
#     'user_id': 704972,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/c176240cfcbeda075c655197a2cc8544?s=128&d=identicon&r=PG',
#     'display_name': 'Calaf',
#     'link': 'https://stackoverflow.com/users/704972/calaf'},
#    'is_answered': True,
#    'view_count': 229,
#    'accepted_answer_id': 57545155,
#    'answer_count': 2,
#    'score': 6,
#    'last_activity_date': 1566135975,
#    'creation_date': 1563227335,
#    'last_edit_date': 1563275148,
#    'question_id': 57047587,
#    'link': 'https://stackoverflow.com/questions/57047587/automating-database-creation-for-testing',
#    'title': 'Automating database creation for testing'},
# ...

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here
question3 = SITE.fetch("badges", ids=[6784, 6473])

# %%
question3 = SITE.fetch("answers", sort="votes", ids=[6473,6784])

# %%
question3
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 22349,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=128&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778}]}
